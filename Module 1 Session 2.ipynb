# %%
import cv2
from matplotlib import pyplot as plt
import PIL as pillow
import numpy as np

# %%
image = cv2.imread('sample.png')
plt.imshow(image)

# %%
imagem = cv2.bitwise_not(image)
plt.imshow(imagem)
cv2.imwrite('output.jpeg', imagem)
# Out:
# True

# %%
from PIL import Image
from numpy import array
im_1 = Image.open('sample.png')
arr_1 = array(im_1)
arr_1

im_2 = Image.open('output.jpeg')
arr_2 = array(im_2)
arr_2
# Out:
# array([[[184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178],
#         ...,
#         [184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178]],
#
#        [[184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178],
#         ...,
#         [184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178]],
#
#        [[184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178],
#         ...,
#         [184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178]],
#
#        ...,
#
#        [[184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178],
#         ...,
#         [184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178]],
#
#        [[184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178],
#         ...,
#         [184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178]],
#
#        [[184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178],
#         ...,
#         [184, 142, 178],
#         [184, 142, 178],
#         [184, 142, 178]]], dtype=uint8)
